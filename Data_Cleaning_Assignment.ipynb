# %% [markdown]
# # Data Cleaning Assignment
#
# Q1. Missing Data Identification
#
# Scenario:
#  The hospital suspects incomplete patient records.
#
# Task:
#
# Identify missing values in each column
#
# Calculate percentage of missing data
#
# - Missing values (count):
#
# Age → 600
# Treatment_Cost → 593
# All other columns → 0
#
# Percentage of missing data:
#
# Age → 11.76%
# Treatment_Cost → 11.63%
#
# Conclusion: Only Age and Treatment_Cost have missing values.
#
# Q2. Handling Missing Age
#
# Scenario:
#  Age is critical for medical analysis, but some values are missing.
#
# Task:
#
# Replace missing Age values with an appropriate method
#
# Justify your choice (mean/median)
#
#  Mean Age ≈ 49.6
# Median Age = 50
#
# Since mean ≈ median → data is approximately symmetric
#
#  Chosen method: Median imputation
#  Reason: Median is more robust and avoids influence of any hidden outliers
#
#  - Mean Age ≈ 49.6
# Median Age = 50
#
# Since mean ≈ median → data is approximately symmetric
#
# ✔ Chosen method: Median imputation
# ✔ Reason: Median is more robust and avoids influence of any hidden outliers
#
# Q3. Handling Missing Treatment Cost
#
# Scenario:
#  Treatment cost is highly skewed due to expensive treatments.
#
# Task:
#
# Handle missing Treatment_Cost values
#
# Choose the correct imputation method and explain why
#
# - Skewness ≈ 4.48 (highly positively skewed)
#
# Chosen method: Median imputation
# Reason:
#
# Mean would be distorted due to extreme high values
# Median is best for skewed data
#
#
# Q4. Duplicate Patient Records
#
# Scenario:
#  Some patient records were entered multiple times
#
#  Task:
#
# Identify duplicate rows
#
# Remove duplicates
#
# Compare dataset size before and after
#
# - Duplicate rows found: 99
#
# After removing duplicates:
#
# Original size: 5100 rows
# New size: 5001 rows
#
# Q5. Invalid Age Values (Data Quality Check)
#
# Scenario:
#  Some patients have unrealistic age values (e.g., >100 or <0).
#
#  - Invalid age condition: Age < 0 or Age > 100
# Found: 0 records
#
#  No action required (data is clean)
#
# Task:
#
# Detect such records
#
# Decide whether to remove or correct them
#
# Q6. Outlier Detection (Treatment Cost)
#
# Scenario:
#  Extreme treatment costs are affecting analysis.
#
# Task:
#
# Detect outliers using IQR method
#
# Display number of outliers
#
# -  Outliers detected: 50 records
#
# ✔ Method used:
#
# IQR = Q3 − Q1
# Outliers = values outside (Q1 − 1.5×IQR, Q3 + 1.5×IQR)
#
# Q7. Outlier Treatment
#
# Scenario:
# The business team wants to retain all records.
#
# Task:
#
# Apply capping (Winsorization) on Treatment_Cost
#
# Use 5th and 95th percentile
#
# - Applied:
#
# Lower cap = 5th percentile
# Upper cap = 95th percentile
#
# ✔ Effect:
#
# Extreme values replaced with boundary values
# No data loss (important for business requirement)
#
#
#
# Q8. Transformation
#
# Scenario:
#  Treatment cost is highly skewed.
#
# Task:
#
# Apply log transformation
#
# Create a new column
#
# Compare before vs after distribution
#
# - New column created:
#
# Log_Treatment_Cost = log(Treatment_Cost)
#
# Result:
#
# Reduced skewness
# Data becomes more normally distributed
# Better for statistical modeling
#
# Q9. Time-Based Missing Handling
#
# Scenario:
#  Admission dates should follow a logical sequence.
#
# Task:
#
# Sort data by Admission_Date
#
# Apply forward fill or backward fill where appropriate
#
# Justify your choice
#
# - Steps:
#
# Sorted dataset by Admission_Date
# Applied Forward Fill (ffill)
#
# Justification:
#
# Medical records follow a timeline
# Previous values are more logical than future values
# Maintains chronological consistency
